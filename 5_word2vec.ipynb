# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3083, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    # print("i = %i" % i)
    # print("skip window = %i" %skip_window)
    # print("buffer: %s" %buffer)
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index]) # note that max_len=3 so the first one is squeezed out
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
np.array(random.sample(range(10), 3))
# Out:
# array([8, 9, 4])

# %%
batch_size = 128
embedding_size = 256 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print("embed shape %s" % embed.shape)
  print("loss shape %s" % tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size).shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print(similarity.shape)
# Out:
# embed shape (128, 256)
# loss shape (128,)
# (16, 50000)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.903046
# Nearest to united: js, grosso, wallpaper, crystals, contributing, supremacist, excise, quicksort,
# Nearest to as: retrieval, selwyn, interferometry, viceroyalty, kentucky, generalisation, torturing, nag,
# Nearest to for: monarchic, blueprint, bloch, shipwrecked, crabs, bahn, domenico, autonomous,
# Nearest to are: lancashire, revolutionaries, disrupting, bundesl, edith, predates, whitespace, gina,
# Nearest to four: kilometre, saskatchewan, bed, basra, channel, decades, typhoid, alla,
# Nearest to been: mohandas, various, grenada, untouchables, rebadged, adequacy, stravinsky, transwomen,
# Nearest to it: stop, swapping, relevance, steady, electrostatics, brahmi, mistletoe, groucho,
# Nearest to may: introduces, connecting, manchu, promulgation, abbreviations, destruction, gershwin, endowment,
# Nearest to eight: mailing, hermits, strolling, thermotropic, opportunistic, zeppelin, remo, agglomeration,
# Nearest to these: nie, visibly, kicks, juries, bar, onager, wilhelmshaven, destabilization,
# Nearest to see: teutons, contractor, induces, messagepad, advertising, expulsions, flashing, enhancement,
# Nearest to more: evils, roller, chung, forerunner, dorsal, overseer, insomnia, aznar,
# Nearest to two: derby, backers, skyway, incomparable, breezes, respiratory, treaty, includes,
# Nearest to other: mateo, compiles, diatoms, duckling, varepsilon, shawl, ravine, housing,
# Nearest to to: furnace, legislation, cortona, ezra, effector, parte, steels, vocalized,
# Nearest to so: seemed, balanced, secured, inferred, unchallenged, subarctic, notary, animators,
# Average loss at step 2000: 4.377860
# Average loss at step 4000: 3.869658
# Average loss at step 6000: 3.781305
# Average loss at step 8000: 3.760081
# Average loss at step 10000: 3.690224
# Nearest to united: js, wallpaper, grosso, contributing, crystals, quicksort, unfriendly, titration,
# Nearest to as: in, is, with, from, by, was, for, very,
# Nearest to for: on, of, to, by, in, and, with, from,
# Nearest to are: were, is, have, was, with, be, recycle, courant,
# Nearest to four: five, three, seven, eight, six, two, nine, zero,
# Nearest to been: was, be, by, is, grenada, mohandas, mppc, had,
# Nearest to it: he, this, which, she, there, that, also, racing,
# Nearest to may: introduces, escarpment, khaki, arden, antagonistic, manchu, abbreviations, infirmities,
# Nearest to eight: nine, seven, four, five, six, zero, three, two,
# Nearest to these: kicks, visibly, nie, yarns, juries, billing, onager, missoula,
# Nearest to see: teutons, flashing, nuke, messagepad, mammoth, ecmascript, dago, apolitical,
# Nearest to more: roller, confucius, gauguin, forerunner, chung, classrooms, marvelous, worker,
# Nearest to two: four, three, five, six, seven, eight, nine, one,
# Nearest to other: waveguide, compiles, many, intoxicated, torrey, diatoms, sancti, fueling,
# Nearest to to: and, from, for, on, would, in, not, furnace,
# Nearest to so: seemed, balanced, inferred, notary, dwarves, secured, unchallenged, reactants,
# Average loss at step 12000: 3.698670
# Average loss at step 14000: 3.552888
# Average loss at step 16000: 3.441109
# Average loss at step 18000: 3.589522
# Average loss at step 20000: 3.552364
# Nearest to united: js, wallpaper, contributing, grosso, quicksort, crystals, unfriendly, yetzirah,
# Nearest to as: by, reaffirm, is, be, when, with, dien, was,
# Nearest to for: by, and, on, to, of, are, bahn, from,
# Nearest to are: were, is, have, be, by, for, but, fr,
# Nearest to four: five, three, six, seven, eight, zero, two, nine,
# Nearest to been: be, was, were, become, had, by, grenada, also,
# Nearest to it: he, this, which, there, she, that, they, also,
# Nearest to may: can, would, should, will, could, khaki, introduces, escarpment,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to these: some, remedy, yarns, such, juries, nie, billing, kicks,
# Nearest to see: and, flashing, nuke, requirements, teutons, virginals, expulsions, panyu,
# Nearest to more: most, less, confucius, not, exclusively, worker, other, some,
# Nearest to two: three, four, five, six, zero, seven, one, eight,
# Nearest to other: many, most, some, waveguide, torrey, diatoms, more, complex,
# Nearest to to: cortona, would, arabica, for, must, not, volo, can,
# Nearest to so: unchallenged, reactants, notary, dwarves, seemed, conceivable, retardation, soriano,
# Average loss at step 22000: 3.529410
# Average loss at step 24000: 3.542920
# Average loss at step 26000: 3.546366
# Average loss at step 28000: 3.498340
# Average loss at step 30000: 3.474689
# Nearest to united: js, wallpaper, contributing, unfriendly, quicksort, crystals, grosso, yetzirah,
# Nearest to as: by, when, is, was, in, reaffirm, for, had,
# Nearest to for: of, after, by, in, to, with, functionalism, from,
# Nearest to are: were, is, have, other, be, all, being, canadians,
# Nearest to four: six, three, seven, eight, five, nine, two, zero,
# Nearest to been: be, become, was, had, were, by, grenada, is,
# Nearest to it: he, this, there, she, not, they, which, also,
# Nearest to may: can, would, will, could, should, cannot, might, must,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to these: such, some, many, remedy, all, the, yarns, which,
# Nearest to see: flashing, nuke, panyu, whose, can, is, has, but,
# Nearest to more: less, most, confucius, not, exclusively, pickling, ecb, overseer,
# Nearest to two: one, three, five, six, four, eight, seven, zero,
# Nearest to other: are, many, waveguide, most, some, various, ruud, developmental,
# Nearest to to: would, will, can, for, with, could, not, cortona,
# Nearest to so: reactants, unchallenged, notary, dwarves, endorsing, secured, substitutes, soriano,
# Average loss at step 32000: 3.171146
# Average loss at step 34000: 3.368103
# Average loss at step 36000: 3.458588
# Average loss at step 38000: 3.321680
# Average loss at step 40000: 3.426365
# Nearest to united: js, wallpaper, quicksort, unfriendly, contributing, yetzirah, misery, crystals,
# Nearest to as: after, was, very, for, by, is, when, became,
# Nearest to for: after, to, of, at, with, as, in, during,
# Nearest to are: were, is, have, be, include, can, these, all,
# Nearest to four: eight, five, six, seven, three, nine, two, zero,
# Nearest to been: be, become, was, had, were, have, cholesterol, not,
# Nearest to it: he, there, this, she, they, not, also, which,
# Nearest to may: can, would, will, could, should, must, might, khaki,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to these: many, some, such, all, which, remedy, they, their,
# Nearest to see: flashing, but, can, caxton, nuke, rationalize, schwartz, eurythmics,
# Nearest to more: less, most, confucius, not, exclusively, highly, escuela, stag,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to other: many, various, some, these, different, most, waveguide, originate,
# Nearest to to: would, not, and, for, will, who, from, can,
# Nearest to so: reactants, dwarves, unchallenged, notary, secured, forearm, endorsing, narrowest,
# Average loss at step 42000: 3.500788
# Average loss at step 44000: 3.452290
# Average loss at step 46000: 3.359490
# Average loss at step 48000: 3.323555
# Average loss at step 50000: 3.434529
# Nearest to united: js, quicksort, contributing, grosso, unfriendly, wallpaper, misery, yetzirah,
# Nearest to as: by, reaffirm, in, after, acquiescence, before, was, hobby,
# Nearest to for: in, to, after, and, by, functionalism, of, including,
# Nearest to are: were, is, have, be, was, include, these, can,
# Nearest to four: seven, five, six, eight, nine, three, zero, two,
# Nearest to been: be, become, was, had, were, have, since, by,
# Nearest to it: he, this, there, she, they, which, that, also,
# Nearest to may: can, would, will, could, should, must, might, khaki,
# Nearest to eight: nine, seven, four, six, five, zero, three, two,
# Nearest to these: some, many, they, such, which, all, several, their,
# Nearest to see: can, include, flashing, but, eurythmics, nuke, caxton, list,
# Nearest to more: less, most, very, confucius, stronger, highly, exclusively, quite,
# Nearest to two: three, four, five, eight, six, one, seven, zero,
# Nearest to other: many, various, some, different, these, several, such, others,
# Nearest to to: would, for, in, cortona, not, can, thunderbolt, will,
# Nearest to so: reactants, dwarves, notary, unchallenged, narrowest, very, mallory, nor,
# Average loss at step 52000: 3.468195
# Average loss at step 54000: 3.469280
# Average loss at step 56000: 3.406942
# Average loss at step 58000: 3.368751
# Average loss at step 60000: 3.409618
# Nearest to united: js, quicksort, grosso, medway, unfriendly, safeties, yetzirah, contributing,
# Nearest to as: after, and, when, in, had, blogging, became, very,
# Nearest to for: after, against, with, and, in, to, during, when,
# Nearest to are: were, is, have, be, include, these, samoan, those,
# Nearest to four: five, three, six, seven, two, nine, eight, zero,
# Nearest to been: become, be, were, was, had, begun, already, recently,
# Nearest to it: he, she, there, this, they, not, which, often,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to eight: nine, seven, six, five, three, four, zero, one,
# Nearest to these: many, some, such, their, they, several, those, both,
# Nearest to see: include, list, known, nuke, flashing, can, rationalize, caxton,
# Nearest to more: less, most, very, stronger, confucius, exclusively, better, quite,
# Nearest to two: three, five, four, six, seven, nine, one, zero,
# Nearest to other: various, many, these, some, different, such, ills, several,
# Nearest to to: would, could, will, can, in, should, for, furnace,
# Nearest to so: reactants, later, however, truck, dwarves, unchallenged, congratulations, retardation,
# Average loss at step 62000: 3.345774
# Average loss at step 64000: 3.374730
# Average loss at step 66000: 3.348614
# Average loss at step 68000: 3.321651
# Average loss at step 70000: 3.271471
# Nearest to united: js, quicksort, yetzirah, medway, grosso, safeties, clarified, unfriendly,
# Nearest to as: when, after, became, and, was, heraclitus, for, but,
# Nearest to for: after, when, if, to, with, in, during, against,
# Nearest to are: were, is, have, those, including, these, other, was,
# Nearest to four: six, eight, seven, nine, five, three, zero, two,
# Nearest to been: become, be, were, was, had, begun, being, recently,
# Nearest to it: he, there, she, this, they, often, now, who,
# Nearest to may: can, would, could, should, will, must, might, cannot,
# Nearest to eight: nine, six, four, seven, five, three, zero, two,
# Nearest to these: many, some, those, such, they, several, which, both,
# Nearest to see: include, list, but, called, redistribution, refer, known, references,
# Nearest to more: less, most, very, highly, quite, stronger, greater, extremely,
# Nearest to two: four, three, six, five, eight, zero, seven, nine,
# Nearest to other: various, many, different, are, several, these, some, including,
# Nearest to to: would, for, can, not, by, from, will, should,
# Nearest to so: then, however, reactants, if, tantamount, she, nor, uniqueness,
# Average loss at step 72000: 3.296061
# Average loss at step 74000: 3.359417
# Average loss at step 76000: 3.350955
# Average loss at step 78000: 3.334825
# Average loss at step 80000: 3.343424
# Nearest to united: quicksort, js, yetzirah, grosso, medway, unfriendly, southern, safeties,
# Nearest to as: for, when, wished, became, because, oyster, until, hobby,
# Nearest to for: of, while, if, in, at, after, with, as,
# Nearest to are: were, is, have, include, be, those, was, can,
# Nearest to four: five, eight, six, seven, nine, three, two, zero,
# Nearest to been: become, be, was, were, begun, already, had, suffered,
# Nearest to it: he, she, there, this, they, which, itself, who,
# Nearest to may: can, would, could, should, will, might, must, cannot,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to these: many, several, some, both, such, they, which, those,
# Nearest to see: include, can, list, refer, redistribution, but, and, includes,
# Nearest to more: less, most, very, highly, greater, quite, better, repression,
# Nearest to two: three, four, five, eight, seven, six, nine, one,
# Nearest to other: many, various, several, these, their, different, some, including,
# Nearest to to: would, will, could, can, may, should, must, for,
# Nearest to so: if, reactants, however, very, later, uniqueness, nor, she,
# Average loss at step 82000: 3.344132
# Average loss at step 84000: 3.395528
# Average loss at step 86000: 3.364382
# Average loss at step 88000: 3.372729
# Average loss at step 90000: 3.319671
# Nearest to united: js, yetzirah, safeties, grosso, medway, quicksort, unfriendly, clarified,
# Nearest to as: heraclitus, lorre, including, unhcr, is, became, lasker, badges,
# Nearest to for: after, while, against, to, from, of, on, during,
# Nearest to are: were, is, have, include, was, although, those, including,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to been: be, become, was, were, had, begun, already, by,
# Nearest to it: he, she, there, this, they, which, but, itself,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to eight: six, nine, seven, five, four, zero, three, one,
# Nearest to these: several, some, many, such, those, different, their, both,
# Nearest to see: list, include, refer, includes, known, teen, nuke, but,
# Nearest to more: less, most, very, greater, highly, better, stronger, too,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to other: various, many, different, are, american, slavic, most, some,
# Nearest to to: in, from, for, will, and, would, through, by,
# Nearest to so: if, but, uniqueness, reactants, sometimes, she, later, then,
# Average loss at step 92000: 3.185336
# Average loss at step 94000: 3.327046
# Average loss at step 96000: 3.355909
# Average loss at step 98000: 3.357701
# Average loss at step 100000: 3.363366
# Nearest to united: js, clarified, safeties, grosso, southern, yetzirah, west, contributing,
# Nearest to as: lorre, badges, before, became, after, when, zen, conti,
# Nearest to for: by, against, after, in, during, if, of, while,
# Nearest to are: were, is, have, those, although, be, while, include,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to been: become, be, was, had, were, begun, already, remained,
# Nearest to it: he, she, there, this, they, often, still, now,
# Nearest to may: can, could, will, would, should, must, might, cannot,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to these: several, many, some, such, both, those, they, all,
# Nearest to see: list, include, can, may, includes, called, including, teen,
# Nearest to more: less, most, very, greater, highly, extremely, better, longer,
# Nearest to two: three, four, one, six, seven, five, eight, nine,
# Nearest to other: various, different, many, some, slavic, most, several, colonialism,
# Nearest to to: would, will, cortona, can, in, could, viewer, must,
# Nearest to so: then, if, thus, before, later, sometimes, too, but,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window * 2), dtype=np.int32)
  # print(batch.shape)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # print("i = %i" % i)
    # print("buffer: %s" %buffer)
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      # print("j = %i" % j)
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      labels[i, 0] = buffer[skip_window]
      batch[i][j] = buffer[target]
      # print(batch)
    buffer.append(data[data_index]) # note that max_len=3 so the first one is squeezed out
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[b] for b in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['a', 'originated'], ['term', 'as'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['term', 'a', 'anarchism', 'originated'], ['originated', 'term', 'as', 'of'], ['of', 'a', 'as', 'abuse'], ['term', 'a', 'abuse', 'first'], ['of', 'first', 'used', 'term'], ['of', 'abuse', 'against', 'used'], ['early', 'abuse', 'first', 'against'], ['early', 'working', 'first', 'used']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 256 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), axis=1)
  
  print("embed shape %s" % embed.shape)
  print("loss shape %s" % tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size).shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print(similarity.shape)
# Out:
# embed shape (128, 256)
# loss shape (128,)
# (16, 50000)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.396837
# Nearest to if: forrester, enzymatic, yana, anh, pitot, danann, roberto, boisbaudran,
# Nearest to s: catv, ridley, milky, tidy, minbari, theirs, lh, erdrich,
# Nearest to can: prometheus, clog, cages, classis, congolese, juice, kirby, valproate,
# Nearest to used: obstruct, untersuchungen, greenland, swordfish, multipurpose, linnaean, peacefully, talbot,
# Nearest to american: tarquin, merci, inflating, frequency, waco, eats, tip, firmware,
# Nearest to during: hope, guez, christchurch, summations, prudent, separators, haran, oxidase,
# Nearest to most: sliders, licklider, drinkordie, burgoyne, raccoon, discoid, define, monsoon,
# Nearest to of: uncertainties, decoding, allston, hatfield, fasciculata, vespasian, mimicking, anchors,
# Nearest to into: logics, jahan, respectability, bounty, hyperbola, portfolios, mutual, practicing,
# Nearest to war: milliseconds, bok, hurl, johnnie, mosque, perrin, stv, shogun,
# Nearest to known: agrarianism, more, radiocarbon, humanoid, automate, aggressively, lexington, unveils,
# Nearest to is: admissions, multicellular, discover, unsustainable, begining, venera, marvelous, encompasses,
# Nearest to over: stabilize, palazzo, lesbian, sloth, adventure, gru, hutchinson, freleng,
# Nearest to other: elect, teimanim, tiryns, magnificence, haliotis, variant, disinfectant, ryu,
# Nearest to see: collusion, gholas, isla, stare, inlet, stadium, select, intact,
# Nearest to on: game, thoth, heard, gnp, rankings, essene, southerly, russel,
# Average loss at step 2000: 4.269698
# Average loss at step 4000: 3.652486
# Average loss at step 6000: 3.459418
# Average loss at step 8000: 3.309075
# Average loss at step 10000: 3.221835
# Nearest to if: forrester, parasites, perpetrated, pitot, tourists, output, aroma, roberto,
# Nearest to s: catastrophes, romanov, his, sergey, heroics, ridley, anthropology, or,
# Nearest to can: may, could, would, will, to, classis, must, might,
# Nearest to used: obstruct, multipurpose, pall, schott, billing, untersuchungen, swordfish, infinitive,
# Nearest to american: german, and, russian, frequency, hopf, rodents, teenager, french,
# Nearest to during: in, detective, guez, kappa, prudent, haran, inferiority, summations,
# Nearest to most: more, raccoon, some, adom, all, rowing, sliders, licklider,
# Nearest to of: for, in, mimicking, from, and, at, geese, shifts,
# Nearest to into: from, as, logics, mutual, on, mad, hyperbola, bottleneck,
# Nearest to war: bok, mosque, deprogramming, milliseconds, zoff, veritas, equation, caius,
# Nearest to known: democratique, radiocarbon, well, regarded, wonders, agrarianism, being, such,
# Nearest to is: was, has, are, be, montevideo, ursa, became, had,
# Nearest to over: lammas, stabilize, lesbian, sloth, elitism, geo, impeccable, executive,
# Nearest to other: many, some, items, hecuba, heterochromatin, adverbs, elect, dravidians,
# Nearest to see: select, stadium, stare, toes, flynn, magnus, barrington, obtainable,
# Nearest to on: in, perot, papier, at, brigham, into, gestures, southerly,
# Average loss at step 12000: 3.257790
# Average loss at step 14000: 3.200847
# Average loss at step 16000: 3.229756
# Average loss at step 18000: 3.176523
# Average loss at step 20000: 3.021659
# Nearest to if: when, pitot, forrester, mcgowan, lewinsky, parasites, for, heywood,
# Nearest to s: his, catastrophes, diffeomorphism, telekinesis, ium, and, prescient, creationist,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to used: known, available, spoken, located, shown, given, seen, preston,
# Nearest to american: english, german, russian, teenager, frequency, british, evil, african,
# Nearest to during: detective, from, at, in, on, within, prudent, hindustani,
# Nearest to most: more, many, all, saxo, emptying, some, morse, allegations,
# Nearest to of: in, for, with, from, mimicking, knowledgeable, defer, foxy,
# Nearest to into: from, between, mad, chrono, on, within, through, herbrand,
# Nearest to war: bok, deprogramming, veritas, yuan, equation, zoff, patronage, atta,
# Nearest to known: used, such, regarded, democratique, well, cohorts, part, elected,
# Nearest to is: was, are, has, be, became, montevideo, does, succeeds,
# Nearest to over: about, lammas, sloth, roses, transylvania, elitism, executive, stabilize,
# Nearest to other: different, more, reiner, many, some, lud, felons, mandible,
# Nearest to see: but, gaddis, flynn, can, jun, obtainable, qaida, pathogens,
# Nearest to on: in, upon, at, and, papier, through, from, histones,
# Average loss at step 22000: 3.119771
# Average loss at step 24000: 3.076184
# Average loss at step 26000: 3.050551
# Average loss at step 28000: 3.071930
# Average loss at step 30000: 3.048690
# Nearest to if: when, though, since, because, where, before, perpetrated, parasites,
# Nearest to s: catastrophes, his, and, cidre, backdoor, fraktion, peugeot, stricture,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to used: known, available, called, seen, considered, given, pall, located,
# Nearest to american: german, french, british, indian, english, russian, teenager, european,
# Nearest to during: in, after, within, before, against, from, by, through,
# Nearest to most: more, some, many, all, lvares, rig, raccoon, adom,
# Nearest to of: in, like, from, including, for, and, hegelians, ideographic,
# Nearest to into: from, through, within, on, herold, mad, portfolios, herbrand,
# Nearest to war: yuan, deprogramming, veritas, yi, annunciation, ani, zoff, furthest,
# Nearest to known: used, such, regarded, well, democratique, elected, responsible, available,
# Nearest to is: was, are, has, be, montevideo, became, exists, were,
# Nearest to over: about, through, across, lammas, off, nearly, roses, bandits,
# Nearest to other: many, different, various, some, several, more, lud, felons,
# Nearest to see: but, can, flynn, called, known, jun, and, qaida,
# Nearest to on: upon, in, about, into, from, through, between, by,
# Average loss at step 32000: 2.851487
# Average loss at step 34000: 2.995576
# Average loss at step 36000: 2.982108
# Average loss at step 38000: 2.981934
# Average loss at step 40000: 2.976681
# Nearest to if: when, since, though, because, where, before, sloppy, planetary,
# Nearest to s: catastrophes, luxemburg, her, his, isbn, undersecretary, is, analogues,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to used: known, written, available, seen, given, located, considered, described,
# Nearest to american: german, british, french, indian, european, italian, african, australian,
# Nearest to during: in, after, within, before, when, by, from, since,
# Nearest to most: more, some, many, less, all, adom, lvares, particularly,
# Nearest to of: from, mimicking, for, same, accrue, interjection, although, ideographic,
# Nearest to into: from, through, up, within, including, herbrand, morpheus, musicals,
# Nearest to war: yuan, atta, deprogramming, annunciation, wars, bevan, wally, naturalized,
# Nearest to known: used, such, regarded, called, classified, see, described, part,
# Nearest to is: was, has, be, are, became, proximal, becomes, does,
# Nearest to over: about, off, through, across, concluding, out, upon, roses,
# Nearest to other: fukuda, different, many, various, more, larger, felons, kvac,
# Nearest to see: known, flynn, can, external, including, but, and, cravings,
# Nearest to on: upon, through, at, over, brigham, under, subshell, mahor,
# Average loss at step 42000: 2.991220
# Average loss at step 44000: 2.997219
# Average loss at step 46000: 2.938001
# Average loss at step 48000: 2.903265
# Average loss at step 50000: 2.878057
# Nearest to if: when, where, though, since, because, before, after, for,
# Nearest to s: catastrophes, isbn, his, american, ium, whose, and, diversions,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to used: known, seen, written, available, mentioned, called, given, considered,
# Nearest to american: british, german, indian, italian, and, australian, john, s,
# Nearest to during: in, after, from, when, within, before, at, since,
# Nearest to most: more, many, some, less, all, several, particularly, other,
# Nearest to of: in, during, from, for, interjection, allegheny, and, including,
# Nearest to into: from, through, within, up, out, around, under, mad,
# Nearest to war: annunciation, yuan, theodosius, atta, bevan, ministry, denouncing, counter,
# Nearest to known: used, such, regarded, described, available, called, classified, considered,
# Nearest to is: was, has, are, became, be, maintains, becomes, does,
# Nearest to over: about, across, out, through, off, nearly, lammas, around,
# Nearest to other: various, different, most, several, sustaining, more, many, including,
# Nearest to see: can, called, may, external, avowed, yea, known, including,
# Nearest to on: upon, in, at, through, from, during, under, mahor,
# Average loss at step 52000: 2.927323
# Average loss at step 54000: 2.892482
# Average loss at step 56000: 2.888845
# Average loss at step 58000: 2.771235
# Average loss at step 60000: 2.859430
# Nearest to if: when, though, where, since, before, until, because, then,
# Nearest to s: catastrophes, his, whose, and, ium, isbn, ridley, selective,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to used: known, seen, considered, available, called, mentioned, located, found,
# Nearest to american: british, indian, german, italian, australian, european, canadian, english,
# Nearest to during: in, after, when, at, within, through, before, from,
# Nearest to most: more, many, less, some, especially, particularly, use, because,
# Nearest to of: in, although, from, include, including, during, and, capitoline,
# Nearest to into: through, from, within, under, between, during, in, has,
# Nearest to war: annunciation, yuan, atta, theodosius, wars, bevan, dago, wasteland,
# Nearest to known: used, such, regarded, available, called, defined, considered, opposed,
# Nearest to is: was, has, are, does, be, seems, becomes, refers,
# Nearest to over: across, about, around, within, between, through, lammas, during,
# Nearest to other: various, several, different, including, individual, older, others, many,
# Nearest to see: but, can, refer, include, flynn, includes, called, references,
# Nearest to on: upon, through, in, at, under, during, scheduler, preceding,
# Average loss at step 62000: 2.865216
# Average loss at step 64000: 2.794407
# Average loss at step 66000: 2.790472
# Average loss at step 68000: 2.738804
# Average loss at step 70000: 2.814220
# Nearest to if: when, since, where, before, though, after, until, because,
# Nearest to s: his, catastrophes, whose, isbn, dtd, pronunciations, ridley, american,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to used: known, seen, available, mentioned, referred, found, appeared, located,
# Nearest to american: australian, british, german, italian, indian, european, canadian, french,
# Nearest to during: after, in, since, under, when, although, on, following,
# Nearest to most: more, less, many, some, particularly, especially, all, very,
# Nearest to of: in, although, for, mimicking, conceit, from, during, including,
# Nearest to into: through, from, within, with, under, musicals, between, herold,
# Nearest to war: wars, hercule, annunciation, bevan, theodosius, atta, dago, wasteland,
# Nearest to known: such, used, regarded, available, defined, described, opposed, possible,
# Nearest to is: was, has, are, be, became, becomes, does, represents,
# Nearest to over: around, across, about, nearly, off, within, lammas, tico,
# Nearest to other: various, different, many, individual, dystopian, older, larger, several,
# Nearest to see: include, can, references, louisville, includes, external, refer, auburn,
# Nearest to on: upon, in, during, under, through, within, at, against,
# Average loss at step 72000: 2.820755
# Average loss at step 74000: 2.660335
# Average loss at step 76000: 2.829766
# Average loss at step 78000: 2.851352
# Average loss at step 80000: 2.808062
# Nearest to if: when, where, since, though, before, then, because, ll,
# Nearest to s: isbn, whose, catastrophes, narration, supercharged, unleashing, his, graf,
# Nearest to can: could, will, would, may, might, should, must, cannot,
# Nearest to used: known, seen, considered, mentioned, available, intended, released, described,
# Nearest to american: british, australian, italian, german, european, french, indian, canadian,
# Nearest to during: in, after, before, by, until, when, throughout, under,
# Nearest to most: many, more, less, some, all, because, use, throughout,
# Nearest to of: in, and, during, defer, for, including, although, from,
# Nearest to into: through, within, from, out, with, around, on, between,
# Nearest to war: wars, cup, hercule, ministry, zonker, bevan, atta, annunciation,
# Nearest to known: used, regarded, such, available, possible, intended, called, considered,
# Nearest to is: was, has, are, becomes, became, be, remains, refers,
# Nearest to over: around, about, across, nearly, lammas, beck, off, tico,
# Nearest to other: various, many, several, individual, including, different, eastern, bloemfontein,
# Nearest to see: include, includes, references, but, called, louisville, can, external,
# Nearest to on: upon, in, through, during, mahor, at, around, under,
# Average loss at step 82000: 2.681493
# Average loss at step 84000: 2.792783
# Average loss at step 86000: 2.759384
# Average loss at step 88000: 2.771048
# Average loss at step 90000: 2.761769
# Nearest to if: when, though, before, where, since, after, until, although,
# Nearest to s: isbn, his, whose, catastrophes, and, prescient, stricture, cockroaches,
# Nearest to can: could, would, will, may, should, must, might, cannot,
# Nearest to used: known, mentioned, described, seen, given, applied, referred, intended,
# Nearest to american: australian, italian, british, indian, french, european, canadian, austrian,
# Nearest to during: in, after, since, before, under, at, throughout, although,
# Nearest to most: more, some, many, less, all, especially, both, particularly,
# Nearest to of: for, mimicking, including, trypanosomiasis, capitoline, interjection, advisory, in,
# Nearest to into: through, within, from, out, under, around, down, symmetrical,
# Nearest to war: wars, bevan, dago, cup, ministry, yuan, annunciation, ferdinand,
# Nearest to known: used, regarded, called, such, available, intended, possible, seen,
# Nearest to is: was, has, are, became, becomes, appears, provides, does,
# Nearest to over: around, about, across, off, between, within, nearly, through,
# Nearest to other: various, many, different, several, individual, major, including, older,
# Nearest to see: include, but, references, external, known, list, includes, note,
# Nearest to on: upon, in, at, within, through, and, about, by,
# Average loss at step 92000: 2.696506
# Average loss at step 94000: 2.747540
# Average loss at step 96000: 2.716869
# Average loss at step 98000: 2.375092
# Average loss at step 100000: 2.411675
# Nearest to if: when, before, though, where, since, did, until, follows,
# Nearest to s: isbn, whose, catastrophes, american, was, her, wrote, his,
# Nearest to can: could, will, would, should, might, must, may, cannot,
# Nearest to used: known, referred, called, seen, mentioned, described, considered, applied,
# Nearest to american: english, australian, british, canadian, russian, french, german, italian,
# Nearest to during: in, at, after, before, when, until, despite, throughout,
# Nearest to most: more, less, many, some, especially, all, throughout, because,
# Nearest to of: in, from, mimicking, capitoline, despite, to, with, and,
# Nearest to into: through, within, from, under, up, down, out, after,
# Nearest to war: wars, entertainer, atta, dago, bmj, cup, ministry, bevan,
# Nearest to known: used, regarded, such, available, called, seen, possible, named,
# Nearest to is: was, has, became, are, be, remains, seems, becomes,
# Nearest to over: around, across, about, off, nearly, out, within, through,
# Nearest to other: various, others, different, including, several, numerous, foreign, pieced,
# Nearest to see: include, external, references, called, list, known, refer, according,
# Nearest to on: upon, in, at, through, from, against, news, within,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
